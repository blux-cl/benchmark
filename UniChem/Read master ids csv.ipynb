# %%
import pandas as pd
import numpy as np

# %%
unichem = pd.read_csv("unichem_master_ids.csv")
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3331: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
unichem[unichem['chebi'] == 85146] #carboxymethylcellulose
# Out:
#         uci         chembl drugbank  pdb  gtopdb  pubchem_dotf kegg_ligand  \
# 500001  NaN  CHEMBL1909054      NaN  NaN     NaN           NaN      D07622
#
#           chebi nih_ncc zinc  ...  brenda rhea chemicalbook swisslipids  \
# 500001  85146.0     NaN  NaN  ...     NaN  NaN          NaN         NaN
#
#        dailymed clinicaltrials rxnorm  MedChemExpress  probes_and_drugs  \
# 500001      NaN            NaN    NaN             NaN               NaN
#
#             CAS-RN
# 500001  9000-11-07
#
# [1 rows x 42 columns]

# %%
unichem[unichem['chebi'] == 27607] #thymol
# Out:
#              uci       chembl drugbank  pdb  gtopdb  pubchem_dotf kegg_ligand  \
# 499999  527491.0  CHEMBL29411  DB02513  IPB  2499.0           NaN      C09908
#
#           chebi nih_ncc              zinc  ...  brenda rhea chemicalbook  \
# 499999  27607.0     NaN  ZINC000000967597  ...  8200.0  NaN    CB6672399
#
#        swisslipids dailymed clinicaltrials  rxnorm  MedChemExpress  \
# 499999         NaN   THYMOL         THYMOL  THYMOL        HY-N6810
#
#         probes_and_drugs CAS-RN
# 499999          PD009428    NaN
#
# [1 rows x 42 columns]

# %%
unichem[unichem['chebi'] == 17148] #putrescine
# Out:
#              uci       chembl drugbank  pdb  gtopdb  pubchem_dotf kegg_ligand  \
# 500000  551550.0  CHEMBL46257  DB01917  PUT  2388.0           NaN      C02896
#
#           chebi nih_ncc              zinc  ...    brenda rhea chemicalbook  \
# 500000  17148.0     NaN  ZINC000005828633  ...  109948.0  NaN    CB8210315
#
#        swisslipids dailymed clinicaltrials rxnorm  MedChemExpress  \
# 500000         NaN      NaN     PUTRESCINE    NaN             NaN
#
#         probes_and_drugs CAS-RN
# 500000          PD008302    NaN
#
# [1 rows x 42 columns]

# %%
unichem[unichem['chebi'] == 17620] #ferulic acid
# Out:
#              uci       chembl drugbank  pdb  gtopdb  pubchem_dotf kegg_ligand  \
# 257705  257706.0  CHEMBL32749  DB07767  FER     NaN   125299308.0      C01494
#
#           chebi nih_ncc              zinc  ...    brenda rhea chemicalbook  \
# 257705  17620.0     NaN  ZINC000000058258  ...  233988.0  NaN    CB0337151
#
#        swisslipids dailymed clinicaltrials        rxnorm  MedChemExpress  \
# 257705         NaN      NaN            NaN  FERULIC ACID        HY-N0060
#
#         probes_and_drugs    CAS-RN
# 257705          PD001909  537-98-4
#
# [1 rows x 42 columns]

# %%
unichem[unichem['chebi'] == 16243] #quercetin
# Out:
#              uci    chembl drugbank  pdb  gtopdb  pubchem_dotf kegg_ligand  \
# 310495  310496.0  CHEMBL50  DB04216  QUE  5346.0    12014036.0      C00389
#
#           chebi nih_ncc              zinc  ...   brenda rhea chemicalbook  \
# 310495  16243.0     NaN  ZINC000003869685  ...  43252.0  NaN    CB3230765
#
#        swisslipids   dailymed clinicaltrials     rxnorm  MedChemExpress  \
# 310495         NaN  QUERCETIN      QUERCETIN  QUERCETIN        HY-18085
#
#         probes_and_drugs    CAS-RN
# 310495          PD001643  117-39-5
#
# [1 rows x 42 columns]
